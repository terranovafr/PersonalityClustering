# %%
import pandas as pd
df_model = pd.read_csv('../data/data-preprocessed.csv',index_col=0)
df_model
# Out:
#         extroversion  neurotic  agreeable  conscientious  open  TimeSpent
# id
# 370320           1.8       3.0        3.0            1.2   3.8       1.69
# 319353           1.4       3.2        3.0            1.2   4.0       2.81
# 65779            2.8       2.4        2.6            4.4   3.6       2.02
# 55385            2.0       2.8        3.4            3.4   3.4       2.70
# 563841           4.0       2.8        2.4            3.0   4.4       0.95
# ...              ...       ...        ...            ...   ...        ...
# 903127           4.6       2.4        2.4            1.2   4.2       1.19
# 547179           1.4       2.8        2.6            1.8   3.0       3.38
# 101688           3.2       3.6        1.8            3.6   2.6       1.84
# 396191           2.0       3.0        2.0            3.2   3.6       2.47
# 772141           4.0       3.6        2.4            3.4   4.2       1.20
#
# [46875 rows x 6 columns]

# %%
n_samples, n_features = df_model.shape
print(n_samples)
print(n_features)
# Out:
# 46875
# 6

# %%
from matplotlib import pyplot as plt
df_model.iloc[:,0:5].plot.hist()
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(df_model)
