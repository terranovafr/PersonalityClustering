# %%
import pandas as pd
df_model = pd.read_csv('../data/data-preprocessed.csv',index_col=0)
df_model.head()
# Out:
#         extroversion  neurotic  agreeable  conscientious  open  TimeSpent
# id
# 638380           2.6       3.8        3.0            2.8   3.6       1.85
# 370101           3.8       3.6        2.8            3.0   4.2       4.72
# 43658            3.6       3.4        2.6            4.8   3.6       1.90
# 725182           3.0       3.6        2.0            4.2   3.8       2.34
# 575654           3.2       3.4        2.8            2.6   4.4       1.84

# %%
from matplotlib import pyplot as plt
df_model.iloc[:,0:5].plot.hist()
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks")
sns.pairplot(df_model)
